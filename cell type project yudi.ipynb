# %%
import pandas as pd

df = pd.read_excel ('neurophysiology_data.xlsx')
mouse_df = pd.DataFrame (df)
mouse_df
# Out:
#      CellCapacitance  InputResistance  RestingMembranePotential  \
# 0                NaN            457.0                     -57.9
# 1                NaN             59.0                     -61.0
# 2                NaN             63.0                     -70.0
# 3                NaN             40.7                     -73.7
# 4                NaN             46.0                     -63.0
# ..               ...              ...                       ...
# 379              NaN              NaN                       NaN
# 380             26.8            996.5                       NaN
# 381              NaN              NaN                     -45.0
# 382              NaN              NaN                       NaN
# 383              NaN              NaN                       NaN
#
#      MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 0                     NaN            64.0             1.5             NaN
# 1                    17.0            92.1             NaN           -43.0
# 2                    31.0             NaN             NaN           -35.5
# 3                     NaN            61.0             NaN           -54.0
# 4                    21.0             NaN             NaN             NaN
# ..                    ...             ...             ...             ...
# 379                   NaN            68.5             2.4           -38.3
# 380                   NaN             NaN             NaN             NaN
# 381                   NaN            58.0             NaN           -26.0
# 382                   NaN             NaN             NaN             NaN
# 383                   NaN            72.3             1.8           -50.6
#
#      Rheobase  FiringFrequency  AhpDuration  ...  Temp   Age  Weight  \
# 0         NaN              NaN          NaN  ...  34.0   6.5     NaN
# 1         NaN              NaN          NaN  ...  32.0  44.0     NaN
# 2         NaN              NaN          NaN  ...  31.0  49.0     NaN
# 3         NaN             0.23          NaN  ...  37.0  80.5   330.0
# 4         NaN              NaN          NaN  ...  32.0  38.0   135.0
# ..        ...              ...          ...  ...   ...   ...     ...
# 379       NaN             3.30          NaN  ...  24.0  17.0     NaN
# 380       NaN              NaN          NaN  ...  34.0  14.0     NaN
# 381       NaN              NaN          NaN  ...  31.0  28.0     NaN
# 382       NaN              NaN          NaN  ...  37.0  63.0   287.5
# 383       NaN              NaN          NaN  ...  27.0  18.0     NaN
#
#                                         NeuronType  \
# 0                    Abducens nucleus motor neuron
# 1    Amygdala basolateral nucleus pyramidal neuron
# 2    Amygdala basolateral nucleus pyramidal neuron
# 3    Amygdala basolateral nucleus pyramidal neuron
# 4    Amygdala basolateral nucleus pyramidal neuron
# ..                                             ...
# 379         Ventral tegmental area dopamine neuron
# 380         Ventral tegmental area dopamine neuron
# 381         Ventral tegmental area dopamine neuron
# 382         Ventral tegmental area dopamine neuron
# 383         Ventral tegmental area dopamine neuron
#
#                                                  Title  PubYear  \
# 0    A- T- and H-type currents shape intrinsic firi...     2003
# 1    Distinct subtypes of cholecystokinin (CCK)-con...     2009
# 2    Noradrenergic excitation of a subpopulation of...     2008
# 3    Cellular mechanisms of infralimbic and prelimb...     2002
# 4    Cholinergic responses of morphologically and e...     1997
# ..                                                 ...      ...
# 379  A-type K+ current of dopamine and GABA neurons...     2006
# 380  Spontaneous activity and properties of two typ...     2005
# 381  The ventral tegmental area revisited: is there...     2006
# 382  Cannabinoid receptors in the bed nucleus of th...     2008
# 383  Nigral GABAergic inhibition upon mesencephalic...     2004
#
#                                        PubmedLink  \
# 0    http://www.ncbi.nlm.nih.gov/pubmed/12651919/
# 1    http://www.ncbi.nlm.nih.gov/pubmed/19164102/
# 2    http://www.ncbi.nlm.nih.gov/pubmed/18950687/
# 3    http://www.ncbi.nlm.nih.gov/pubmed/11756516/
# 4     http://www.ncbi.nlm.nih.gov/pubmed/9153654/
# ..                                            ...
# 379  http://www.ncbi.nlm.nih.gov/pubmed/16611837/
# 380  http://www.ncbi.nlm.nih.gov/pubmed/15659533/
# 381  http://www.ncbi.nlm.nih.gov/pubmed/16959856/
# 382  http://www.ncbi.nlm.nih.gov/pubmed/18923026/
# 383  http://www.ncbi.nlm.nih.gov/pubmed/15128394/
#
#                                 DataTableLinks  \
# 0    http://neuroelectro.org/data_table/11076/
# 1      http://neuroelectro.org/data_table/242/
# 2    http://neuroelectro.org/data_table/26660/
# 3     http://neuroelectro.org/data_table/2952/
# 4    http://neuroelectro.org/data_table/24186/
# ..                                         ...
# 379   http://neuroelectro.org/data_table/5675/
# 380    http://neuroelectro.org/data_table/628/
# 381   http://neuroelectro.org/data_table/9300/
# 382  http://neuroelectro.org/data_table/10856/
# 383  http://neuroelectro.org/data_table/16614/
#
#                                 ArticleLink    LastAuthor
# 0    http://neuroelectro.org/article/45731/     Debanne D
# 1    http://neuroelectro.org/article/26026/    Rainnie DG
# 2    http://neuroelectro.org/article/30833/    Yanagawa Y
# 3    http://neuroelectro.org/article/37269/      Grace AA
# 4    http://neuroelectro.org/article/82009/     Criado JM
# ..                                      ...           ...
# 379  http://neuroelectro.org/article/32828/      Appel SB
# 380  http://neuroelectro.org/article/34223/     Weight FF
# 381  http://neuroelectro.org/article/40636/     Fields HL
# 382  http://neuroelectro.org/article/57457/     Georges F
# 383  http://neuroelectro.org/article/72902/  Takakusaki K
#
# [384 rows x 43 columns]

# %%
CA3_list = []
for i in mouse_df['NeuronType']:
    if 'CA3'in i:
        CA3_list.append (i)
print (CA3_list)
# Out:
# ['Hippocampus CA3 basket cell', 'Hippocampus CA3 lacunosum moleculare neuron', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 stratum radiatum giant cell', 'Hippocampus CA3 trilaminar neuron']

# %%
#pull out all the rows where "CA3" is in the NeuroType column and create a new DataFrame 
df_CA3 = df[df['NeuronType'].str.contains('CA3')].reset_index(drop=True)
df_CA3
# Out:
#     CellCapacitance  InputResistance  RestingMembranePotential  \
# 0               NaN            122.9                       NaN
# 1               NaN            315.1                       NaN
# 2               NaN            454.0                     -57.0
# 3             424.0            164.0                     -76.0
# 4               NaN            307.0                     -58.0
# 5               NaN             79.8                     -72.6
# 6               NaN             55.5                     -63.8
# 7               NaN            180.0                     -65.0
# 8               NaN            160.1                       NaN
# 9               NaN            102.0                     -72.0
# 10              NaN            595.0                     -57.0
# 11              NaN            167.3                       NaN
#
#     MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 0                   11.2             NaN            0.54             NaN
# 1                   33.3             NaN            0.84             NaN
# 2                   91.0            85.0            1.70           -39.0
# 3                   61.0             NaN            0.79           -58.0
# 4                   71.0            80.0            1.70           -35.0
# 5                    NaN            74.5             NaN           -55.5
# 6                    NaN            92.2            0.55             NaN
# 7                    NaN            73.9            1.30             NaN
# 8                   37.2             NaN            1.18             NaN
# 9                   21.1             NaN             NaN             NaN
# 10                  67.0            76.0            1.10           -35.0
# 11                  16.9             NaN            0.57             NaN
#
#     Rheobase  FiringFrequency  AhpDuration  ...  Temp   Age  Weight  \
# 0        NaN              NaN         0.98  ...  29.0  21.5     NaN
# 1        NaN              NaN         5.15  ...  29.0  21.5     NaN
# 2        NaN              NaN          NaN  ...  22.0  11.0     NaN
# 3        NaN              NaN          NaN  ...  31.0  42.0     NaN
# 4        NaN              NaN          NaN  ...  23.0  19.0     NaN
# 5        NaN            118.0          NaN  ...  30.0  70.0   425.0
# 6        NaN              NaN          NaN  ...  31.0  53.0     NaN
# 7        NaN              NaN          NaN  ...  32.0  42.5     NaN
# 8        NaN              NaN         8.33  ...  29.0  21.5     NaN
# 9        NaN              NaN          NaN  ...  33.0   3.5     NaN
# 10       NaN              NaN          NaN  ...  23.0  19.0     NaN
# 11       NaN              NaN         0.82  ...  29.0  21.5     NaN
#
#                                      NeuronType  \
# 0                   Hippocampus CA3 basket cell
# 1   Hippocampus CA3 lacunosum moleculare neuron
# 2                Hippocampus CA3 pyramidal cell
# 3                Hippocampus CA3 pyramidal cell
# 4                Hippocampus CA3 pyramidal cell
# 5                Hippocampus CA3 pyramidal cell
# 6                Hippocampus CA3 pyramidal cell
# 7                Hippocampus CA3 pyramidal cell
# 8                Hippocampus CA3 pyramidal cell
# 9                Hippocampus CA3 pyramidal cell
# 10  Hippocampus CA3 stratum radiatum giant cell
# 11            Hippocampus CA3 trilaminar neuron
#
#                                                 Title  PubYear  \
# 0   Differential involvement of oriens/pyramidale ...     2005
# 1   Differential involvement of oriens/pyramidale ...     2005
# 2   Medium afterhyperpolarization and firing patte...     2001
# 3   Stable mossy fiber long-term potentiation requ...     2010
# 4   Electrophysiological characterization of "gian...     2001
# 5   Permanent reduction of seizure threshold in po...     2000
# 6   Local circuit abnormalities in chronically epi...     1998
# 7   Blockade of neuronal activity during hippocamp...     2000
# 8   Differential involvement of oriens/pyramidale ...     2005
# 9   Heterogeneous populations of cells mediate spo...     2000
# 10  Electrophysiological characterization of "gian...     2001
# 11  Differential involvement of oriens/pyramidale ...     2005
#
#                                       PubmedLink  \
# 0   http://www.ncbi.nlm.nih.gov/pubmed/15486016/
# 1   http://www.ncbi.nlm.nih.gov/pubmed/15486016/
# 2   http://www.ncbi.nlm.nih.gov/pubmed/11353015/
# 3   http://www.ncbi.nlm.nih.gov/pubmed/20881117/
# 4   http://www.ncbi.nlm.nih.gov/pubmed/11353016/
# 5   http://www.ncbi.nlm.nih.gov/pubmed/10758114/
# 6    http://www.ncbi.nlm.nih.gov/pubmed/9425181/
# 7   http://www.ncbi.nlm.nih.gov/pubmed/10751443/
# 8   http://www.ncbi.nlm.nih.gov/pubmed/15486016/
# 9   http://www.ncbi.nlm.nih.gov/pubmed/10799755/
# 10  http://www.ncbi.nlm.nih.gov/pubmed/11353016/
# 11  http://www.ncbi.nlm.nih.gov/pubmed/15486016/
#
#                                DataTableLinks  \
# 0   http://neuroelectro.org/data_table/10636/
# 1   http://neuroelectro.org/data_table/10636/
# 2    http://neuroelectro.org/data_table/1004/
# 3    http://neuroelectro.org/data_table/1721/
# 4    http://neuroelectro.org/data_table/1000/
# 5    http://neuroelectro.org/data_table/1118/
# 6    http://neuroelectro.org/data_table/1335/
# 7    http://neuroelectro.org/data_table/3178/
# 8   http://neuroelectro.org/data_table/10636/
# 9   http://neuroelectro.org/data_table/22053/
# 10   http://neuroelectro.org/data_table/1000/
# 11  http://neuroelectro.org/data_table/10636/
#
#                                ArticleLink         LastAuthor
# 0   http://neuroelectro.org/article/44738/            Buhl EH
# 1   http://neuroelectro.org/article/44738/            Buhl EH
# 2    http://neuroelectro.org/article/4981/    Sciancalepore M
# 3   http://neuroelectro.org/article/27590/             Beck H
# 4   http://neuroelectro.org/article/28502/    Sciancalepore M
# 5   http://neuroelectro.org/article/34646/           CrÈpel V
# 6   http://neuroelectro.org/article/34848/           Swann JW
# 7   http://neuroelectro.org/article/37531/           Swann JW
# 8   http://neuroelectro.org/article/44738/            Buhl EH
# 9   http://neuroelectro.org/article/79240/  Sanchez-Andres JV
# 10  http://neuroelectro.org/article/28502/    Sciancalepore M
# 11  http://neuroelectro.org/article/44738/            Buhl EH
#
# [12 rows x 43 columns]

# %%
df_CA1 = df[df['NeuronType'].str.contains('CA1')].reset_index(drop=True)
#df_CA3.loc[:,'NeuronType'] = 'CA3'

df_CA1
# Out:
#     CellCapacitance  InputResistance  RestingMembranePotential  \
# 0               NaN           110.00                    -63.00
# 1             112.5           142.50                       NaN
# 2               NaN            96.90                    -66.20
# 3               NaN            70.60                    -60.00
# 4               NaN           284.00                    -59.80
# 5             107.0           185.00                    -63.00
# 6              63.0           239.50                    -63.50
# 7               NaN            74.70                    -58.30
# 8               NaN           267.00                    -62.00
# 9             199.5           200.50                       NaN
# 10              NaN           111.00                       NaN
# 11              NaN           111.00                    -60.10
# 12              NaN            35.40                    -69.90
# 13              NaN           237.80                    -61.70
# 14              NaN            55.40                    -66.20
# 15              NaN           260.00                    -68.00
# 16              NaN            36.10                    -68.50
# 17              NaN            28.40                    -64.30
# 18              NaN            45.70                    -64.30
# 19              NaN              NaN                       NaN
# 20              NaN           120.80                    -65.90
# 21            165.0           108.50                       NaN
# 22              NaN            37.75                    -67.10
# 23              NaN            53.85                    -61.67
# 24              NaN            32.60                    -63.10
# 25              NaN            53.30                    -64.50
# 26              NaN           100.60                    -64.80
# 27              NaN            61.10                       NaN
# 28              NaN              NaN                    -64.40
# 29              NaN            30.48                    -72.55
# 30              NaN           326.72                    -61.38
# 31              NaN           149.80                    -72.47
# 32              NaN            55.76                    -62.00
# 33              NaN            42.90                    -62.00
# 34              NaN           143.10                    -70.70
# 35              NaN            82.35                    -58.70
# 36              NaN           100.00                    -65.00
# 37              NaN            52.30                    -59.90
# 38              NaN           151.00                    -65.60
# 39              NaN           107.00                    -62.80
# 40              NaN           108.00                       NaN
# 41              NaN            44.09                    -58.28
# 42              NaN            82.00                    -69.00
# 43              NaN            86.00                    -63.00
#
#     MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 0                  12.00             NaN            0.40             NaN
# 1                  10.35             NaN             NaN             NaN
# 2                    NaN             NaN             NaN          -55.40
# 3                    NaN             NaN            0.67             NaN
# 4                  13.30             NaN             NaN             NaN
# 5                  19.00           56.00            0.80          -33.00
# 6                  15.00           57.50            0.83          -30.50
# 7                    NaN             NaN            0.80             NaN
# 8                  32.00             NaN            0.80             NaN
# 9                  39.60             NaN             NaN             NaN
# 10                   NaN           82.60             NaN          -37.90
# 11                   NaN             NaN            1.52          -46.20
# 12                   NaN           92.00            0.83          -58.90
# 13                 29.20             NaN             NaN             NaN
# 14                 40.30          112.00            0.95          -46.30
# 15                 40.00             NaN            0.90             NaN
# 16                   NaN           93.55            0.76          -57.05
# 17                 13.70           87.00             NaN          -52.30
# 18                   NaN           90.20             NaN          -53.90
# 19                   NaN             NaN             NaN             NaN
# 20                   NaN             NaN             NaN             NaN
# 21                 17.05             NaN             NaN             NaN
# 22                   NaN             NaN             NaN          -56.70
# 23                   NaN             NaN             NaN             NaN
# 24                   NaN             NaN             NaN             NaN
# 25                   NaN             NaN             NaN          -53.20
# 26                 27.90          106.80            1.60          -51.50
# 27                   NaN             NaN             NaN             NaN
# 28                   NaN           77.30             NaN             NaN
# 29                   NaN             NaN             NaN             NaN
# 30                   NaN             NaN             NaN          -48.78
# 31                   NaN           70.94             NaN          -33.81
# 32                   NaN           77.37             NaN             NaN
# 33                 11.00           77.60            0.76             NaN
# 34                   NaN             NaN            1.20          -50.40
# 35                   NaN             NaN             NaN             NaN
# 36                 39.00             NaN            1.90          -38.00
# 37                   NaN             NaN            1.15             NaN
# 38                   NaN             NaN             NaN          -49.00
# 39                 29.80             NaN             NaN             NaN
# 40                 61.00             NaN             NaN             NaN
# 41                 27.64             NaN             NaN          -38.29
# 42                 19.40             NaN             NaN             NaN
# 43                 50.00             NaN            1.90          -31.00
#
#     Rheobase  FiringFrequency  AhpDuration  ...  Temp    Age  Weight  \
# 0        NaN              NaN          NaN  ...  32.0   12.0     NaN
# 1        NaN              NaN          NaN  ...  35.5   20.0     NaN
# 2        NaN              NaN          NaN  ...  30.0   21.0   175.0
# 3        NaN              NaN          NaN  ...  34.5   50.0   150.0
# 4        NaN            206.0          NaN  ...  32.0   28.0     NaN
# 5        NaN              NaN         73.0  ...  33.0   17.5     NaN
# 6        NaN              NaN         72.0  ...  33.0   17.5     NaN
# 7        NaN              NaN          NaN  ...  34.5   50.0   150.0
# 8        NaN              NaN          NaN  ...  32.0   12.0     NaN
# 9        NaN              NaN          NaN  ...  35.5   20.0     NaN
# 10       NaN              NaN          NaN  ...  22.0    6.0     NaN
# 11       NaN              NaN          NaN  ...  22.0   70.0     NaN
# 12       NaN              NaN          NaN  ...  33.5   44.5   175.0
# 13       NaN              NaN          NaN  ...  22.0   70.0     NaN
# 14     213.0              NaN          NaN  ...  35.0   38.5     NaN
# 15       NaN              NaN          NaN  ...  32.0   12.0     NaN
# 16       NaN              NaN          NaN  ...  33.5   44.5   150.0
# 17       NaN              NaN          NaN  ...  33.5   44.5   175.0
# 18       NaN              NaN          NaN  ...  33.5   44.5   175.0
# 19       NaN              NaN          NaN  ...  22.0   13.0     NaN
# 20       NaN              NaN          8.1  ...  22.0  210.0     NaN
# 21       NaN              NaN          NaN  ...  35.5   20.0     NaN
# 22       NaN              NaN          NaN  ...  32.0   31.5     NaN
# 23       NaN              NaN          NaN  ...  33.5  105.0     NaN
# 24       NaN             33.2          NaN  ...  22.0   22.0     NaN
# 25       NaN              NaN          NaN  ...  30.0   21.0   175.0
# 26     700.0              NaN          NaN  ...  28.0   57.5     NaN
# 27       NaN              NaN          NaN  ...  32.5   49.0     NaN
# 28       NaN              NaN          NaN  ...  31.0   64.5   280.0
# 29       NaN              NaN          NaN  ...  32.0   70.5     NaN
# 30       NaN              NaN          NaN  ...  23.0   12.5     NaN
# 31       NaN              NaN          NaN  ...  30.0   18.0     NaN
# 32       NaN              NaN          NaN  ...  32.0  120.0     NaN
# 33       NaN              NaN          NaN  ...  31.0   63.0     NaN
# 34       NaN              NaN          NaN  ...  32.0   30.0     NaN
# 35     151.0              NaN          NaN  ...  22.0  120.0     NaN
# 36       NaN              NaN          NaN  ...  33.5   44.5   150.0
# 37       NaN              NaN          NaN  ...  34.5   50.0   150.0
# 38      70.0              NaN          NaN  ...  31.0   14.0     NaN
# 39       NaN             86.0          NaN  ...  32.0   28.0     NaN
# 40       NaN              NaN          NaN  ...  35.0   25.0     NaN
# 41       NaN              NaN          NaN  ...  22.0   17.5     NaN
# 42       NaN              NaN          NaN  ...  33.0    3.5     NaN
# 43       NaN              NaN          NaN  ...  33.5   44.5   150.0
#
#                                            NeuronType  \
# 0                         Hippocampus CA1 basket cell
# 1                         Hippocampus CA1 basket cell
# 2                         Hippocampus CA1 basket cell
# 3                         Hippocampus CA1 basket cell
# 4                         Hippocampus CA1 basket cell
# 5                          Hippocampus CA1 ivy neuron
# 6                  Hippocampus CA1 neurogliaform cell
# 7                  Hippocampus CA1 neurogliaform cell
# 8   Hippocampus CA1 oriens lacunosum moleculare ne...
# 9   Hippocampus CA1 oriens lacunosum moleculare ne...
# 10                     Hippocampus CA1 pyramidal cell
# 11                     Hippocampus CA1 pyramidal cell
# 12                     Hippocampus CA1 pyramidal cell
# 13                     Hippocampus CA1 pyramidal cell
# 14                     Hippocampus CA1 pyramidal cell
# 15                     Hippocampus CA1 pyramidal cell
# 16                     Hippocampus CA1 pyramidal cell
# 17                     Hippocampus CA1 pyramidal cell
# 18                     Hippocampus CA1 pyramidal cell
# 19                     Hippocampus CA1 pyramidal cell
# 20                     Hippocampus CA1 pyramidal cell
# 21                     Hippocampus CA1 pyramidal cell
# 22                     Hippocampus CA1 pyramidal cell
# 23                     Hippocampus CA1 pyramidal cell
# 24                     Hippocampus CA1 pyramidal cell
# 25                     Hippocampus CA1 pyramidal cell
# 26                     Hippocampus CA1 pyramidal cell
# 27                     Hippocampus CA1 pyramidal cell
# 28                     Hippocampus CA1 pyramidal cell
# 29                     Hippocampus CA1 pyramidal cell
# 30                     Hippocampus CA1 pyramidal cell
# 31                     Hippocampus CA1 pyramidal cell
# 32                     Hippocampus CA1 pyramidal cell
# 33                     Hippocampus CA1 pyramidal cell
# 34                     Hippocampus CA1 pyramidal cell
# 35                     Hippocampus CA1 pyramidal cell
# 36                     Hippocampus CA1 pyramidal cell
# 37                     Hippocampus CA1 pyramidal cell
# 38                     Hippocampus CA1 pyramidal cell
# 39                     Hippocampus CA1 pyramidal cell
# 40                     Hippocampus CA1 pyramidal cell
# 41                     Hippocampus CA1 pyramidal cell
# 42                     Hippocampus CA1 pyramidal cell
# 43                Hippocampus CA1 radiatum giant cell
#
#                                                 Title  PubYear  \
# 0   Transition to seizures in the isolated immatur...     2008
# 1   Differences in subthreshold resonance of hippo...     2010
# 2   Temporal overlap of excitatory and inhibitory ...     1999
# 3   Unitary IPSPs evoked by interneurons at the st...     1998
# 4   NMDA receptor-dependent long-term potentiation...     2007
# 5   Common origins of hippocampal Ivy and nitric o...     2010
# 6   Common origins of hippocampal Ivy and nitric o...     2010
# 7   Unitary IPSPs evoked by interneurons at the st...     1998
# 8   Transition to seizures in the isolated immatur...     2008
# 9   Differences in subthreshold resonance of hippo...     2010
# 10  Hyperexcitability of distal dendrites in hippo...     2007
# 11  A spontaneous mutation involving Kcnq2 (Kv7.2)...     2006
# 12  KCNQ/M channels control spike afterdepolarizat...     2004
# 13  Alterations in intrinsic membrane properties a...     2011
# 14  Resting and active properties of pyramidal neu...     2000
# 15  Transition to seizures in the isolated immatur...     2008
# 16  Proximal persistent Na+ channels drive spike a...     2005
# 17  Extracellular calcium modulates persistent sod...     2001
# 18  Initiation of network bursts by Ca2+-dependent...     2001
# 19  Cholinergic stimulation enhances cytosolic cal...     2000
# 20  Slow afterhyperpolarization governs the develo...     2004
# 21  Differences in subthreshold resonance of hippo...     2010
# 22  Heterogeneous firing behavior during ictal-lik...     2012
# 23  Disrupting function of FK506-binding protein 1...     2011
# 24  Cholecystokinin increases GABA release by inhi...     1997
# 25  Temporal overlap of excitatory and inhibitory ...     1999
# 26  Enhanced intrinsic excitability and EPSP-spike...     2012
# 27  Group I mGluRs increase excitability of hippoc...     2002
# 28  Intracellular correlates of spatial memory acq...     2001
# 29  Mechanism for increased hippocampal synaptic s...     2001
# 30  Hypoxia-induced neonatal seizures diminish sil...     2011
# 31  A functional null mutation of SCN1B in a patie...     2009
# 32  Early and simultaneous emergence of multiple h...     2006
# 33  Depression of synaptic transmission by vascula...     2005
# 34  Focal deletion of the adenosine A1 receptor in...     2003
# 35  Elevated postsynaptic [Ca2+]i and L-type calci...     2001
# 36  Unique properties of NMDA receptors enhance sy...     2000
# 37  Unitary IPSPs evoked by interneurons at the st...     1998
# 38  Synaptic ionotropic glutamate receptors and pl...     2009
# 39  NMDA receptor-dependent long-term potentiation...     2007
# 40  Mechanisms of electrical coupling between pyra...     1997
# 41  Differential corticosteroid modulation of inhi...     2009
# 42  Heterogeneous populations of cells mediate spo...     2000
# 43  Unique properties of NMDA receptors enhance sy...     2000
#
#                                       PubmedLink  \
# 0   http://www.ncbi.nlm.nih.gov/pubmed/17991696/
# 1   http://www.ncbi.nlm.nih.gov/pubmed/20421280/
# 2   http://www.ncbi.nlm.nih.gov/pubmed/10087347/
# 3    http://www.ncbi.nlm.nih.gov/pubmed/9503336/
# 4   http://www.ncbi.nlm.nih.gov/pubmed/17884930/
# 5   http://www.ncbi.nlm.nih.gov/pubmed/20147544/
# 6   http://www.ncbi.nlm.nih.gov/pubmed/20147544/
# 7    http://www.ncbi.nlm.nih.gov/pubmed/9503336/
# 8   http://www.ncbi.nlm.nih.gov/pubmed/17991696/
# 9   http://www.ncbi.nlm.nih.gov/pubmed/20421280/
# 10  http://www.ncbi.nlm.nih.gov/pubmed/17202472/
# 11  http://www.ncbi.nlm.nih.gov/pubmed/16481438/
# 12  http://www.ncbi.nlm.nih.gov/pubmed/15140933/
# 13  http://www.ncbi.nlm.nih.gov/pubmed/22131424/
# 14  http://www.ncbi.nlm.nih.gov/pubmed/11067982/
# 15  http://www.ncbi.nlm.nih.gov/pubmed/17991696/
# 16  http://www.ncbi.nlm.nih.gov/pubmed/16237175/
# 17  http://www.ncbi.nlm.nih.gov/pubmed/11404402/
# 18  http://www.ncbi.nlm.nih.gov/pubmed/11283235/
# 19  http://www.ncbi.nlm.nih.gov/pubmed/10878106/
# 20  http://www.ncbi.nlm.nih.gov/pubmed/15190096/
# 21  http://www.ncbi.nlm.nih.gov/pubmed/20421280/
# 22  http://www.ncbi.nlm.nih.gov/pubmed/22157126/
# 23  http://www.ncbi.nlm.nih.gov/pubmed/21289178/
# 24   http://www.ncbi.nlm.nih.gov/pubmed/9185537/
# 25  http://www.ncbi.nlm.nih.gov/pubmed/10087347/
# 26  http://www.ncbi.nlm.nih.gov/pubmed/22157122/
# 27  http://www.ncbi.nlm.nih.gov/pubmed/12091536/
# 28  http://www.ncbi.nlm.nih.gov/pubmed/11495958/
# 29  http://www.ncbi.nlm.nih.gov/pubmed/11287462/
# 30  http://www.ncbi.nlm.nih.gov/pubmed/22171027/
# 31  http://www.ncbi.nlm.nih.gov/pubmed/19710327/
# 32  http://www.ncbi.nlm.nih.gov/pubmed/16571755/
# 33  http://www.ncbi.nlm.nih.gov/pubmed/16192378/
# 34  http://www.ncbi.nlm.nih.gov/pubmed/12843280/
# 35  http://www.ncbi.nlm.nih.gov/pubmed/11739583/
# 36  http://www.ncbi.nlm.nih.gov/pubmed/10864941/
# 37   http://www.ncbi.nlm.nih.gov/pubmed/9503336/
# 38  http://www.ncbi.nlm.nih.gov/pubmed/19103683/
# 39  http://www.ncbi.nlm.nih.gov/pubmed/17884930/
# 40   http://www.ncbi.nlm.nih.gov/pubmed/9405530/
# 41  http://www.ncbi.nlm.nih.gov/pubmed/19261881/
# 42  http://www.ncbi.nlm.nih.gov/pubmed/10799755/
# 43  http://www.ncbi.nlm.nih.gov/pubmed/10864941/
#
#                                        DataTableLinks  \
# 0            http://neuroelectro.org/data_table/8047/
# 1            http://neuroelectro.org/data_table/8283/
# 2            http://neuroelectro.org/data_table/8497/
# 3           http://neuroelectro.org/data_table/10082/
# 4           http://neuroelectro.org/data_table/11371/
# 5            http://neuroelectro.org/data_table/1838/
# 6            http://neuroelectro.org/data_table/1838/
# 7           http://neuroelectro.org/data_table/10082/
# 8            http://neuroelectro.org/data_table/8047/
# 9            http://neuroelectro.org/data_table/8283/
# 10           http://neuroelectro.org/data_table/2248/
# 11           http://neuroelectro.org/data_table/2379/
# 12           http://neuroelectro.org/data_table/2607/
# 13           http://neuroelectro.org/data_table/1514/
# 14  http://neuroelectro.org/data_table/1064/; http...
# 15           http://neuroelectro.org/data_table/8047/
# 16           http://neuroelectro.org/data_table/2411/
# 17           http://neuroelectro.org/data_table/3036/
# 18           http://neuroelectro.org/data_table/8144/
# 19           http://neuroelectro.org/data_table/8213/
# 20           http://neuroelectro.org/data_table/5533/
# 21           http://neuroelectro.org/data_table/8283/
# 22             http://neuroelectro.org/data_table/14/
# 23           http://neuroelectro.org/data_table/1666/
# 24          http://neuroelectro.org/data_table/10754/
# 25           http://neuroelectro.org/data_table/8497/
# 26             http://neuroelectro.org/data_table/11/
# 27            http://neuroelectro.org/data_table/912/
# 28            http://neuroelectro.org/data_table/985/
# 29           http://neuroelectro.org/data_table/1007/
# 30           http://neuroelectro.org/data_table/1497/
# 31           http://neuroelectro.org/data_table/1929/
# 32           http://neuroelectro.org/data_table/2372/
# 33           http://neuroelectro.org/data_table/2430/
# 34           http://neuroelectro.org/data_table/2742/
# 35  http://neuroelectro.org/data_table/2956/; http...
# 36           http://neuroelectro.org/data_table/3156/
# 37          http://neuroelectro.org/data_table/10082/
# 38          http://neuroelectro.org/data_table/10291/
# 39          http://neuroelectro.org/data_table/11371/
# 40           http://neuroelectro.org/data_table/6245/
# 41  http://neuroelectro.org/data_table/12568/; htt...
# 42          http://neuroelectro.org/data_table/22053/
# 43           http://neuroelectro.org/data_table/3156/
#
#                                ArticleLink         LastAuthor
# 0   http://neuroelectro.org/article/11195/          Carlen PL
# 1   http://neuroelectro.org/article/27366/            H·jos N
# 2   http://neuroelectro.org/article/33579/          Stelzer A
# 3   http://neuroelectro.org/article/43072/            Buhl EH
# 4   http://neuroelectro.org/article/46287/        Kullmann DM
# 5   http://neuroelectro.org/article/35516/          McBain CJ
# 6   http://neuroelectro.org/article/35516/          McBain CJ
# 7   http://neuroelectro.org/article/43072/            Buhl EH
# 8   http://neuroelectro.org/article/11195/          Carlen PL
# 9   http://neuroelectro.org/article/27366/            H·jos N
# 10   http://neuroelectro.org/article/4321/            Tang CM
# 11   http://neuroelectro.org/article/5686/          Wilcox KS
# 12   http://neuroelectro.org/article/5989/            Yaari Y
# 13   http://neuroelectro.org/article/9075/            Klann E
# 14  http://neuroelectro.org/article/10775/         Spruston N
# 15  http://neuroelectro.org/article/11195/          Carlen PL
# 16  http://neuroelectro.org/article/11852/            Yaari Y
# 17  http://neuroelectro.org/article/11918/            Yaari Y
# 18  http://neuroelectro.org/article/14171/            Yaari Y
# 19  http://neuroelectro.org/article/24843/          Barish ME
# 20  http://neuroelectro.org/article/25371/      Disterhoft JF
# 21  http://neuroelectro.org/article/27366/            H·jos N
# 22  http://neuroelectro.org/article/31997/       Nedergaard S
# 23  http://neuroelectro.org/article/32797/       Landfield PW
# 24  http://neuroelectro.org/article/33395/          Lupica CR
# 25  http://neuroelectro.org/article/33579/          Stelzer A
# 26  http://neuroelectro.org/article/33697/        Chattarji S
# 27  http://neuroelectro.org/article/34461/         Abraham WC
# 28  http://neuroelectro.org/article/34529/           Alkon DL
# 29  http://neuroelectro.org/article/34560/           Dumas TC
# 30  http://neuroelectro.org/article/35011/          Jensen FE
# 31  http://neuroelectro.org/article/35646/            Isom LL
# 32  http://neuroelectro.org/article/36399/         Thibault O
# 33  http://neuroelectro.org/article/36504/       Scharfman HE
# 34  http://neuroelectro.org/article/36991/          Greene RW
# 35  http://neuroelectro.org/article/37275/       Landfield PW
# 36  http://neuroelectro.org/article/37497/            Yaari Y
# 37  http://neuroelectro.org/article/43072/            Buhl EH
# 38  http://neuroelectro.org/article/43596/         Seeburg PH
# 39  http://neuroelectro.org/article/46287/        Kullmann DM
# 40  http://neuroelectro.org/article/47709/          Carlen PL
# 41  http://neuroelectro.org/article/59872/            Segal M
# 42  http://neuroelectro.org/article/79240/  Sanchez-Andres JV
# 43  http://neuroelectro.org/article/37497/            Yaari Y
#
# [44 rows x 43 columns]

# %%
#df_new = pd.DataFrame()
#df = pd.DataFrame()
#for i in mouse_df['NeuronType']:
    #if 'CA1' in i:
        #df = mouse_df[mouse_df['NeuronType']==i]
        #df_new = df_new.append(df)
        
#df_new

# %%
for col in df_new.columns: 
    print(col)
# Out:
# CellCapacitance
# InputResistance
# RestingMembranePotential
# MembraneTimeConstant
# SpikeAmplitude
# SpikeHalfWidth
# SpikeThreshold
# Rheobase
# FiringFrequency
# AhpDuration
# CellDiameter
# AccessResistance
# SagRatio
# SpikeOvershoot
# CellSurfaceArea
# AhpAmplitude
# FiSlope
# SpontaneousFiringRate
# FastAhpAmplitude
# FastAhpDuration
# SlowAhpAmplitude
# SlowAhpDuration
# SpikeWidth
# AdpAmplitude
# AdpDuration
# SpikePeak
# AdaptationRatio
# Species
# Strain
# ElectrodeType
# PrepType
# JxnPotential
# JxnOffset
# Temp
# Age
# Weight
# NeuronType
# Title
# PubYear
# PubmedLink
# DataTableLinks
# ArticleLink
# LastAuthor

# %%
df_CA3[['RestingMembranePotential','SpikeAmplitude','SpikeHalfWidth','SpikeThreshold','SagRatio']]
# Out:
#     RestingMembranePotential  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 0                        NaN             NaN            0.54             NaN
# 1                        NaN             NaN            0.84             NaN
# 2                      -57.0            85.0            1.70           -39.0
# 3                      -76.0             NaN            0.79           -58.0
# 4                      -58.0            80.0            1.70           -35.0
# 5                      -72.6            74.5             NaN           -55.5
# 6                      -63.8            92.2            0.55             NaN
# 7                      -65.0            73.9            1.30             NaN
# 8                        NaN             NaN            1.18             NaN
# 9                      -72.0             NaN             NaN             NaN
# 10                     -57.0            76.0            1.10           -35.0
# 11                       NaN             NaN            0.57             NaN
#
#     SagRatio
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN

# %%
df_CA1[['RestingMembranePotential','SpikeAmplitude','SpikeHalfWidth','SpikeThreshold','SagRatio']]
# Out:
#     RestingMembranePotential  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 0                     -63.00             NaN            0.40             NaN
# 1                        NaN             NaN             NaN             NaN
# 2                     -66.20             NaN             NaN          -55.40
# 3                     -60.00             NaN            0.67             NaN
# 4                     -59.80             NaN             NaN             NaN
# 5                     -63.00           56.00            0.80          -33.00
# 6                     -63.50           57.50            0.83          -30.50
# 7                     -58.30             NaN            0.80             NaN
# 8                     -62.00             NaN            0.80             NaN
# 9                        NaN             NaN             NaN             NaN
# 10                       NaN           82.60             NaN          -37.90
# 11                    -60.10             NaN            1.52          -46.20
# 12                    -69.90           92.00            0.83          -58.90
# 13                    -61.70             NaN             NaN             NaN
# 14                    -66.20          112.00            0.95          -46.30
# 15                    -68.00             NaN            0.90             NaN
# 16                    -68.50           93.55            0.76          -57.05
# 17                    -64.30           87.00             NaN          -52.30
# 18                    -64.30           90.20             NaN          -53.90
# 19                       NaN             NaN             NaN             NaN
# 20                    -65.90             NaN             NaN             NaN
# 21                       NaN             NaN             NaN             NaN
# 22                    -67.10             NaN             NaN          -56.70
# 23                    -61.67             NaN             NaN             NaN
# 24                    -63.10             NaN             NaN             NaN
# 25                    -64.50             NaN             NaN          -53.20
# 26                    -64.80          106.80            1.60          -51.50
# 27                       NaN             NaN             NaN             NaN
# 28                    -64.40           77.30             NaN             NaN
# 29                    -72.55             NaN             NaN             NaN
# 30                    -61.38             NaN             NaN          -48.78
# 31                    -72.47           70.94             NaN          -33.81
# 32                    -62.00           77.37             NaN             NaN
# 33                    -62.00           77.60            0.76             NaN
# 34                    -70.70             NaN            1.20          -50.40
# 35                    -58.70             NaN             NaN             NaN
# 36                    -65.00             NaN            1.90          -38.00
# 37                    -59.90             NaN            1.15             NaN
# 38                    -65.60             NaN             NaN          -49.00
# 39                    -62.80             NaN             NaN             NaN
# 40                       NaN             NaN             NaN             NaN
# 41                    -58.28             NaN             NaN          -38.29
# 42                    -69.00             NaN             NaN             NaN
# 43                    -63.00             NaN            1.90          -31.00
#
#     SagRatio
# 0        NaN
# 1       0.93
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9       0.56
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14      0.79
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21      0.82
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       NaN
# 33       NaN
# 34       NaN
# 35       NaN
# 36       NaN
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

fig,ax = plt.subplots()
data = [df_CA1, df_CA3]

ax.boxplot(data)
ax.set_xticklabels
ax.set_ylabel
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1f89cb681533> in <module>
#       6 data = [df_CA1, df_CA3]
#       7
# ----> 8 ax.boxplot(data)
#       9 ax.set_xticklabels
#      10 ax.set_ylabel
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3668
#    3669         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
# -> 3670                                        labels=labels, autorange=autorange)
#    3671         if notch is None:
#    3672             notch = rcParams['boxplot.notch']
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1243
#    1244     # convert X to a list of lists
# -> 1245     X = _reshape_2D(X, "X")
#    1246
#    1247     ncols = len(X)
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in _reshape_2D(X, name)
#    1418     """
#    1419     # Iterate over columns for ndarrays, over rows otherwise.
# -> 1420     X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
#    1421     if len(X) == 0:
#    1422         return [[]]
#
# /opt/conda/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: cannot copy sequence with size 44 to array axis with dimension 43
