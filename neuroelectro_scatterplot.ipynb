# %%
import pandas as pd

df = pd.read_excel ('neurophysiology_data.xlsx')
mouse_df = pd.DataFrame (df)
mouse_df
# Out:
#      CellCapacitance  InputResistance  RestingMembranePotential  \
# 0                NaN            457.0                     -57.9
# 1                NaN             59.0                     -61.0
# 2                NaN             63.0                     -70.0
# 3                NaN             40.7                     -73.7
# 4                NaN             46.0                     -63.0
# ..               ...              ...                       ...
# 379              NaN              NaN                       NaN
# 380             26.8            996.5                       NaN
# 381              NaN              NaN                     -45.0
# 382              NaN              NaN                       NaN
# 383              NaN              NaN                       NaN
#
#      MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 0                     NaN            64.0             1.5             NaN
# ...

# %%
CA3_list = []
for i in mouse_df['NeuronType']:
    if 'CA3'in i:
        CA3_list.append (i)
print (CA3_list)
# Out:
# ['Hippocampus CA3 basket cell', 'Hippocampus CA3 lacunosum moleculare neuron', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 pyramidal cell', 'Hippocampus CA3 stratum radiatum giant cell', 'Hippocampus CA3 trilaminar neuron']

# %%
#pull out all the rows where "CA3" is in the NeuroType column and create a new DataFrame 
df_CA3 = df[df['NeuronType'].str.contains('CA3')].reset_index(drop=True)
df_CA3
# Out:
#     CellCapacitance  InputResistance  RestingMembranePotential  \
# 0               NaN            122.9                       NaN
# 1               NaN            315.1                       NaN
# 2               NaN            454.0                     -57.0
# 3             424.0            164.0                     -76.0
# 4               NaN            307.0                     -58.0
# 5               NaN             79.8                     -72.6
# 6               NaN             55.5                     -63.8
# 7               NaN            180.0                     -65.0
# 8               NaN            160.1                       NaN
# 9               NaN            102.0                     -72.0
# 10              NaN            595.0                     -57.0
# 11              NaN            167.3                       NaN
#
#     MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# ...

# %%
df_CA1 = df[df['NeuronType'].str.contains('CA1')].reset_index(drop=True)
#df_CA3.loc[:,'NeuronType'] = 'CA3'

df_CA1
# Out:
#     CellCapacitance  InputResistance  RestingMembranePotential  \
# 0               NaN           110.00                    -63.00
# 1             112.5           142.50                       NaN
# 2               NaN            96.90                    -66.20
# 3               NaN            70.60                    -60.00
# 4               NaN           284.00                    -59.80
# 5             107.0           185.00                    -63.00
# 6              63.0           239.50                    -63.50
# 7               NaN            74.70                    -58.30
# 8               NaN           267.00                    -62.00
# 9             199.5           200.50                       NaN
# 10              NaN           111.00                       NaN
# 11              NaN           111.00                    -60.10
# 12              NaN            35.40                    -69.90
# 13              NaN           237.80                    -61.70
# ...

# %%
df_CA3= df[df['NeuronType'].str.contains('CA3')].reset_index(drop=True)
df_CA3
# Out:
#     CellCapacitance  InputResistance  RestingMembranePotential  \
# 0               NaN            122.9                       NaN
# 1               NaN            315.1                       NaN
# 2               NaN            454.0                     -57.0
# 3             424.0            164.0                     -76.0
# 4               NaN            307.0                     -58.0
# 5               NaN             79.8                     -72.6
# 6               NaN             55.5                     -63.8
# 7               NaN            180.0                     -65.0
# 8               NaN            160.1                       NaN
# 9               NaN            102.0                     -72.0
# 10              NaN            595.0                     -57.0
# 11              NaN            167.3                       NaN
#
#     MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# ...

# %%
df_CA3_pyramidal = df_CA3[df_CA3['NeuronType']=='Hippocampus CA3 pyramidal cell']
df_CA3_pyramidal
# Out:
#    CellCapacitance  InputResistance  RestingMembranePotential  \
# 2              NaN            454.0                     -57.0
# 3            424.0            164.0                     -76.0
# 4              NaN            307.0                     -58.0
# 5              NaN             79.8                     -72.6
# 6              NaN             55.5                     -63.8
# 7              NaN            180.0                     -65.0
# 8              NaN            160.1                       NaN
# 9              NaN            102.0                     -72.0
#
#    MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 2                  91.0            85.0            1.70           -39.0
# 3                  61.0             NaN            0.79           -58.0
# 4                  71.0            80.0            1.70           -35.0
# 5                   NaN            74.5             NaN           -55.5
# ...

# %%
df_CA3_basket_cells = df_CA3[df_CA3['NeuronType']=='Hippocampus CA3 basket cell']
df_CA3_basket_cells
# Out:
#    CellCapacitance  InputResistance  RestingMembranePotential  \
# 0              NaN            122.9                       NaN
#
#    MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 0                  11.2             NaN            0.54             NaN
#
#    Rheobase  FiringFrequency  AhpDuration  ...  Temp   Age  Weight  \
# 0       NaN              NaN         0.98  ...  29.0  21.5     NaN
#
#                     NeuronType  \
# 0  Hippocampus CA3 basket cell
#
#                                                Title  PubYear  \
# 0  Differential involvement of oriens/pyramidale ...     2005
#
#                                      PubmedLink  \
# 0  http://www.ncbi.nlm.nih.gov/pubmed/15486016/
#
#                               DataTableLinks  \
# 0  http://neuroelectro.org/data_table/10636/
#
#                               ArticleLink  LastAuthor
# 0  http://neuroelectro.org/article/44738/     Buhl EH
#
# [1 rows x 43 columns]

# %%
df_CA1_pyramidal = df_CA1[df_CA1['NeuronType']=='Hippocampus CA1 pyramidal cell']
df_CA1_pyramidal
# Out:
#     CellCapacitance  InputResistance  RestingMembranePotential  \
# 10              NaN           111.00                       NaN
# 11              NaN           111.00                    -60.10
# 12              NaN            35.40                    -69.90
# 13              NaN           237.80                    -61.70
# 14              NaN            55.40                    -66.20
# 15              NaN           260.00                    -68.00
# 16              NaN            36.10                    -68.50
# 17              NaN            28.40                    -64.30
# 18              NaN            45.70                    -64.30
# 19              NaN              NaN                       NaN
# 20              NaN           120.80                    -65.90
# 21            165.0           108.50                       NaN
# 22              NaN            37.75                    -67.10
# 23              NaN            53.85                    -61.67
# ...

# %%
df_CA1_basket_cells = df_CA1[df_CA1['NeuronType']=='Hippocampus CA1 basket cell']
df_CA1_basket_cells
# Out:
#    CellCapacitance  InputResistance  RestingMembranePotential  \
# 0              NaN            110.0                     -63.0
# 1            112.5            142.5                       NaN
# 2              NaN             96.9                     -66.2
# 3              NaN             70.6                     -60.0
# 4              NaN            284.0                     -59.8
#
#    MembraneTimeConstant  SpikeAmplitude  SpikeHalfWidth  SpikeThreshold  \
# 0                 12.00             NaN            0.40             NaN
# 1                 10.35             NaN             NaN             NaN
# 2                   NaN             NaN             NaN           -55.4
# 3                   NaN             NaN            0.67             NaN
# 4                 13.30             NaN             NaN             NaN
#
#    Rheobase  FiringFrequency  AhpDuration  ...  Temp   Age  Weight  \
# 0       NaN              NaN          NaN  ...  32.0  12.0     NaN
# ...

# %%
frames = [df_CA3_pyramidal, df_CA3_basket_cells, df_CA1_pyramidal, df_CA1_basket_cells]
df_result = pd.concat(frames)
df_result
# Out:
#     CellCapacitance  InputResistance  RestingMembranePotential  \
# 2               NaN           454.00                    -57.00
# 3             424.0           164.00                    -76.00
# 4               NaN           307.00                    -58.00
# 5               NaN            79.80                    -72.60
# 6               NaN            55.50                    -63.80
# 7               NaN           180.00                    -65.00
# 8               NaN           160.10                       NaN
# 9               NaN           102.00                    -72.00
# 0               NaN           122.90                       NaN
# 10              NaN           111.00                       NaN
# 11              NaN           111.00                    -60.10
# 12              NaN            35.40                    -69.90
# 13              NaN           237.80                    -61.70
# 14              NaN            55.40                    -66.20
# ...

# %%
neuron_types = df_result['NeuronType'].unique()

fig = plt.figure()

for n_type in neuron_types: 
    
    df_new = df_result[df_result['NeuronType'] == n_type]
    
    plt.scatter(df_new['RestingMembranePotential'], 
                df_new['SpikeHalfWidth'],
                label=n_type)
    
plt.ylabel("RestingMembranePotential")
plt.xlabel("SpikeHalfWidth")
plt.legend(loc='best') 
    
plt.show()
